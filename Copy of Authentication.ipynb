# %%
import smtplib, re
import random
from email.mime.text import MIMEText

sender = "dishikalla@gmail.com"
app_password = "gxnvwxesknrcfaxv"

# Email Validation Function

def is_valid_email(email):
    pattern = r'^[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}$'
    return re.fullmatch(pattern, email) is not None

# Keep Asking Until Valid Email

while True:
    receiver = input("Enter your Email: ").strip()

    if is_valid_email(receiver):
        break
    else:
        print("❌ Invalid Email Address! Please enter a valid email.\n")

otp = random.randint(100000,999999)

msg = MIMEText(f"Your OTP is {otp}")
msg["Subject"] = "MoodMentor OTP"
msg["From"] = sender
msg["To"] = receiver

server = smtplib.SMTP("smtp.gmail.com",587)
server.starttls()
server.login(sender, app_password)
server.sendmail(sender, receiver, msg.as_string())
server.quit()

print("OTP Sent!")
print("OTP =", otp)

entered_otp = input("Enter the OTP received in your email: ")

if entered_otp == str(otp):
    print("✅ Email Verified Successfully!")
else:
    print("❌ Invalid OTP")
# Out:
# Enter your Email: dishikalla@gmail.com
# OTP Sent!
# OTP = 823735
# Enter the OTP received in your email: 823735
# ✅ Email Verified Successfully!

# %%
import jwt
from datetime import datetime, timedelta, UTC

# Create your own custom secret key for this specific project
SECRET_KEY = "EmployeeWellnessAnalyticsSecureKey2026_UniqueString"
# For HS256, the recommended secret key length is at least 32 bytes.

payload = {
    "email": receiver,
    "exp": datetime.now(UTC) + timedelta(hours=1)
}

token = jwt.encode(payload, SECRET_KEY, algorithm="HS256")

print("JWT Token:")
print(token)
# Out:
# JWT Token:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6ImRpc2hpa2FsbGFAZ21haWwuY29tIiwiZXhwIjoxNzgzMzU2MDMwfQ.Mev3rXzi7a8XMiV8y9JDtLbfN1UhW_6bUccOSKhB2bk

# %%
try:
    decoded = jwt.decode(token, SECRET_KEY, algorithms=["HS256"])
    print("Token is Valid")
    print(decoded)
except jwt.ExpiredSignatureError:
    print("Token Expired")
except jwt.InvalidTokenError:
    print("Invalid Token")
# Out:
# Token is Valid
# {'email': 'dishikalla@gmail.com', 'exp': 1783356030}

# %%
# !pip install streamlit   --q

# %%
# %%writefile app.py
import streamlit as st

st.set_page_config(
    page_title="MoodMentor",
    page_icon="😊",
    layout="centered"
)

st.title("😊 MoodMentor")

st.subheader("AI-Powered Emotional Wellness System")

choice = st.sidebar.selectbox(
    "Menu",
    ["Home", "Register", "Login"]
)

if choice == "Home":
    st.write("Welcome to MoodMentor")

elif choice == "Register":
    st.header("Register")

elif choice == "Login":
    st.header("Login")

st.header("Create Account")

email = st.text_input("Email")

password = st.text_input(
    "Password",
    type="password"
)

confirm = st.text_input(
    "Confirm Password",
    type="password"
)

if st.button("Send OTP"):
    st.success("OTP Sent")

otp = st.text_input("Enter OTP")

if st.button("Verify OTP"):
    st.success("Email Verified")

st.header("Login")

login_email = st.text_input("Email")

login_password = st.text_input(
    "Password",
    type="password"
)

if st.button("Login"):
    st.success("JWT Generated")

st.title("Dashboard")

st.success("Welcome!")

st.metric("Current Mood", "😊 Happy")

st.metric("Sentiment", "Positive")

menu = st.sidebar.radio(
    "Navigation",
    [
        "Home",
        "Analyze",
        "History",
        "Profile",
        "Logout"
    ]
)

if st.button("Login"):
    if login(email, password):
        st.success("Login Successful")
        st.session_state["logged_in"] = True
    else:
        st.error("Invalid Email or Password")
# Out:
# Writing app.py

# %%
import sqlite3

conn = sqlite3.connect("moodmentor.db")
cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS users (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT,
    email TEXT UNIQUE,
    password TEXT
)
""")

conn.commit()
conn.close()

print("Database created successfully!")
# Out:
# Database created successfully!

# %%
import sqlite3

def register(name, email, password):
    conn = sqlite3.connect("moodmentor.db")
    cursor = conn.cursor()

    try:
        cursor.execute(
            "INSERT INTO users(name, email, password) VALUES (?, ?, ?)",
            (name, email, password)
        )
        conn.commit()
        return True
    except:
        return False
    finally:
        conn.close()

# %%
import sqlite3

def login(email, password):
    conn = sqlite3.connect("moodmentor.db")
    cursor = conn.cursor()

    cursor.execute(
        "SELECT * FROM users WHERE email=? AND password=?",
        (email, password)
    )

    user = cursor.fetchone()
    conn.close()

    return user is not None

# %%
# !pip install -q  pyngrok

# %%
from pyngrok import ngrok

# Set your auth token
ngrok.set_auth_token("3G8UsvAV2jgWlXmnJjGoaWHkDhL_41LTxetuXHvPKHMoYcVjG")

# %%
from pyngrok import ngrok
# !streamlit run app.py &>/content/logs.txt &
public_url = ngrok.connect(8501)
print("Streamlit Public URL:", public_url)
